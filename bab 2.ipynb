# %% [markdown]
# <a href="https://colab.research.google.com/github/kyz97/PRAKTIKUM-BASIS-DATA/blob/main/bab%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BAB 2 – Pengantar Basis Data & DDL
#
# Rangkuman untuk Google Colab
#
#
# ---
#
# 📌 Pengertian Basis Data
#
# Basis data adalah kumpulan data terstruktur yang disimpan dalam tabel dan dapat diolah, dicari, dan dikelola dengan mudah.
# Setiap tabel memiliki:
#
# Field (kolom) → jenis data
#
# Record (baris) → isi data
#
#
# Contoh tabel dalam sistem apotek:
# pasien, obat, pegawai, pembayaran.
#
#
# ---
#
# 📌 Apa itu DBMS?
#
# DBMS (Database Management System) adalah perangkat lunak yang digunakan untuk mengelola basis data.
#
# Fungsinya:
#
# menyimpan dan mengambil data
#
# mencegah duplikasi
#
# menjaga keamanan data
#
# mengatur relasi antar tabel
#
# mengelola transaksi
#
#
# Contoh DBMS:
#
# MySQL / MariaDB
#
# PostgreSQL
#
# SQL Server
#
# Oracle
#
#
#
# ---
#
# 📌 Apa itu MySQL?
#
# MySQL adalah DBMS open-source yang sangat populer karena:
#
# cepat
#
# stabil
#
# gratis
#
# mudah dipelajari
#
# banyak digunakan di aplikasi web
#
#
# Di XAMPP versi terbaru, MySQL digantikan MariaDB, tetapi semua perintah SQL tetap sama.
#
#
# ---
#
# 📌 Mengakses MySQL via Command Line
#
# Masuk ke MySQL:
#
# mysql -u root -p
#
# Keluar dari MySQL:
#
# \q
#
# Lokasi penyimpanan database:
#
# Windows: C:\xampp\mysql\data\
#
# Linux: /opt/lampp/var/mysql/
#
#
#
# ---
#
# 📌 Cara Kerja MySQL Client & Server
#
# MySQL Server → memproses dan menyimpan data
#
# MySQL Client → tempat memasukkan perintah SQL
#
#
# Client yang digunakan:
#
# MySQL Command Line (mysql.exe)
#
# GUI seperti phpMyAdmin (opsional)
#
#
# Semua perintah SQL harus diakhiri tanda ;.
#
#
# ---
#
# 📌 Tipe Data Dasar di MySQL
#
# Beberapa tipe data yang sering digunakan:
#
# Numerik:
#
# INT (bilangan bulat)
#
# FLOAT (bilangan pecahan)
#
#
# Teks:
#
# CHAR (panjang tetap)
#
# VARCHAR (panjang fleksibel)
#
#
# Tanggal/Waktu:
#
# DATE
#
# DATETIME
#
#
# Lainnya:
#
# BLOB (binary data)
#
#
#
# ---
#
# 📌 Apa itu DDL?
#
# DDL (Data Definition Language) adalah perintah SQL yang digunakan untuk mengatur struktur database, bukan mengubah isi datanya.
#
# DDL digunakan untuk:
#
# membuat database
#
# memilih database
#
# menghapus database
#
# membuat/menghapus tabel (dibahas di bab selanjutnya)
#
#
#
# ---
#
# 📌 Perintah Dasar DDL (Paling Penting)
#
# 1️⃣ Membuat Database
#
# CREATE DATABASE nama_database;
#
# 2️⃣ Melihat Semua Database
#
# SHOW DATABASES;
#
# 3️⃣ Mengaktifkan Database
#
# USE nama_database;
#
# 4️⃣ Menghapus Database
#
# DROP DATABASE nama_database;
#
#
# ---
#
# ✔️ Kesimpulan Bab 2
#
# Bab 2 membahas dasar-dasar penting sebelum membuat tabel, yaitu:
#
# apa itu database & DBMS
#
# cara kerja MySQL
#
# cara mengakses MySQL lewat CMD
#
# tipe data umum
#
# perintah-perintah DDL untuk mengelola struktur database
#
#
# Bab ini menjadi fondasi sebelum lanjut ke pembuatan tabel, relasi, dan manipulasi data.
